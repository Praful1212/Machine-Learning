# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Vehicledata.csv')
pd.set_option('max_rows',None)
df
# Out:
#      origin  cylinders  displacement horsepower  weight  acceleration  year  \
# 0         1          8         307.0        130    3504          12.0  1970
# 1         1          8         350.0        165    3693          11.5  1970
# 2         1          8         318.0        150    3436          11.0  1970
# 3         1          8         304.0        150    3433          12.0  1970
# 4         1          8         302.0        140    3449          10.5  1970
# 5         1          8         429.0        198    4341          10.0  1970
# 6         1          8         454.0        220    4354           9.0  1970
# 7         1          8         440.0        215    4312           8.5  1970
# 8         1          8         455.0        225    4425          10.0  1970
# 9         1          8         390.0        190    3850           8.5  1970
# 10        1          8         383.0        170    3563          10.0  1970
# ...

# %%
df.head()
# Out:
#    origin  cylinders  displacement horsepower  weight  acceleration  year  \
# 0       1          8         307.0        130    3504          12.0  1970
# 1       1          8         350.0        165    3693          11.5  1970
# 2       1          8         318.0        150    3436          11.0  1970
# 3       1          8         304.0        150    3433          12.0  1970
# 4       1          8         302.0        140    3449          10.5  1970
#
#                         name  Kilometer_per_liter
# 0  chevrolet chevelle malibu             7.652587
# 1          buick skylark 320             6.377156
# 2         plymouth satellite             7.652587
# 3              amc rebel sst             6.802299
# 4                ford torino             7.227443

# %%
df.tail()
# Out:
#      origin  cylinders  displacement horsepower  weight  acceleration  year  \
# 393       1          4         140.0         86    2790          15.6  1982
# 394       2          4          97.0         52    2130          24.6  1982
# 395       1          4         135.0         84    2295          11.6  1982
# 396       1          4         120.0         79    2625          18.6  1982
# 397       1          4         119.0         82    2720          19.4  1982
#
#                 name  Kilometer_per_liter
# 393  ford mustang gl            11.478880
# 394        vw pickup            18.706323
# 395    dodge rampage            13.604599
# 396      ford ranger            11.904024
# 397       chevy s-10            13.179455

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   origin               398 non-null    int64
#  1   cylinders            398 non-null    int64
#  2   displacement         398 non-null    float64
#  3   horsepower           398 non-null    object
#  4   weight               398 non-null    int64
#  5   acceleration         398 non-null    float64
#  6   year                 398 non-null    int64
#  7   name                 398 non-null    object
#  8   Kilometer_per_liter  398 non-null    float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.describe()
# Out:
#            origin   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean     1.572864    5.454774    193.425879  2970.424623     15.568090
# std      0.802055    1.701004    104.269838   846.841774      2.757689
# min      1.000000    3.000000     68.000000  1613.000000      8.000000
# 25%      1.000000    4.000000    104.250000  2223.750000     13.825000
# 50%      1.000000    4.000000    148.500000  2803.500000     15.500000
# 75%      2.000000    8.000000    262.000000  3608.000000     17.175000
# max      3.000000    8.000000    455.000000  5140.000000     24.800000
#
#               year  Kilometer_per_liter
# count   398.000000           398.000000
# mean   1976.010050             9.997073
# std       3.697627             3.322917
# min    1970.000000             3.826293
# 25%    1973.000000             7.440015
# 50%    1976.000000             9.778305
# 75%    1979.000000            12.329168
# ...

# %%
df.shape
# Out:
# (398, 9)

# %%
df.isna().sum()
# Out:
# origin                 0
# cylinders              0
# displacement           0
# horsepower             0
# weight                 0
# acceleration           0
# year                   0
# name                   0
# Kilometer_per_liter    0
# dtype: int64

# %%
df.isnull().apply(pd.value_counts).T
# Out:
#                      False
# origin                 398
# cylinders              398
# displacement           398
# horsepower             398
# weight                 398
# acceleration           398
# year                   398
# name                   398
# Kilometer_per_liter    398

# %%
df['horsepower']
# Out:
# 0      130
# 1      165
# 2      150
# 3      150
# 4      140
# 5      198
# 6      220
# 7      215
# 8      225
# 9      190
# 10     170
# 11     160
# 12     150
# 13     225
# 14      95
# 15      95
# 16      97
# 17      85
# 18      88
# 19      46
# 20      87
# 21      90
# 22      95
# 23     113
# 24      90
# 25     215
# 26     200
# 27     210
# 28     193
# 29      88
# 30      90
# 31      95
# 32       ?
# 33     100
# 34     105
# 35     100
# 36      88
# 37     100
# 38     165
# 39     175
# 40     153
# 41     150
# 42     180
# 43     170
# 44     175
# 45     110
# 46      72
# 47     100
# 48      88
# 49      86
# 50      90
# 51      70
# 52      76
# 53      65
# 54      69
# 55      60
# 56      70
# 57      95
# 58      80
# 59      54
# 60      90
# 61      86
# 62     165
# 63     175
# 64     150
# 65     153
# 66     150
# 67     208
# 68     155
# 69     160
# 70     190
# 71      97
# 72     150
# 73     130
# 74     140
# 75     150
# ...

# %%
df['horsepower']=df['horsepower'].replace('?',np.nan)

# %%
df['horsepower']=df['horsepower'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   origin               398 non-null    int64
#  1   cylinders            398 non-null    int64
#  2   displacement         398 non-null    float64
#  3   horsepower           392 non-null    float64
#  4   weight               398 non-null    int64
#  5   acceleration         398 non-null    float64
#  6   year                 398 non-null    int64
#  7   name                 398 non-null    object
#  8   Kilometer_per_liter  398 non-null    float64
# dtypes: float64(4), int64(4), object(1)
# memory usage: 28.1+ KB

# %%
df['horsepower']
# Out:
# 0      130.0
# 1      165.0
# 2      150.0
# 3      150.0
# 4      140.0
# 5      198.0
# 6      220.0
# 7      215.0
# 8      225.0
# 9      190.0
# 10     170.0
# 11     160.0
# 12     150.0
# 13     225.0
# 14      95.0
# 15      95.0
# 16      97.0
# 17      85.0
# 18      88.0
# 19      46.0
# 20      87.0
# 21      90.0
# 22      95.0
# 23     113.0
# 24      90.0
# 25     215.0
# 26     200.0
# 27     210.0
# 28     193.0
# 29      88.0
# 30      90.0
# 31      95.0
# 32       NaN
# 33     100.0
# 34     105.0
# 35     100.0
# 36      88.0
# 37     100.0
# 38     165.0
# 39     175.0
# 40     153.0
# 41     150.0
# 42     180.0
# 43     170.0
# 44     175.0
# 45     110.0
# 46      72.0
# 47     100.0
# 48      88.0
# 49      86.0
# 50      90.0
# 51      70.0
# 52      76.0
# 53      65.0
# 54      69.0
# 55      60.0
# 56      70.0
# 57      95.0
# 58      80.0
# 59      54.0
# 60      90.0
# 61      86.0
# 62     165.0
# 63     175.0
# 64     150.0
# 65     153.0
# ...

# %%
df.isna().apply(pd.value_counts).T
# Out:
#                      False  True
# origin               398.0   NaN
# cylinders            398.0   NaN
# displacement         398.0   NaN
# horsepower           392.0   6.0
# weight               398.0   NaN
# acceleration         398.0   NaN
# year                 398.0   NaN
# name                 398.0   NaN
# Kilometer_per_liter  398.0   NaN

# %%
df['horsepower'].fillna(df['horsepower'].median(),inplace=True)

# %%
df.isna().apply(pd.value_counts).T
# Out:
#                      False
# origin                 398
# cylinders              398
# displacement           398
# horsepower             398
# weight                 398
# acceleration           398
# year                   398
# name                   398
# Kilometer_per_liter    398

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   origin               398 non-null    int64
#  1   cylinders            398 non-null    int64
#  2   displacement         398 non-null    float64
#  3   horsepower           398 non-null    float64
#  4   weight               398 non-null    int64
#  5   acceleration         398 non-null    float64
#  6   year                 398 non-null    int64
#  7   name                 398 non-null    object
#  8   Kilometer_per_liter  398 non-null    float64
# dtypes: float64(4), int64(4), object(1)
# memory usage: 28.1+ KB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['name']=le.fit_transform(df['name'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   origin               398 non-null    int64
#  1   cylinders            398 non-null    int64
#  2   displacement         398 non-null    float64
#  3   horsepower           398 non-null    float64
#  4   weight               398 non-null    int64
#  5   acceleration         398 non-null    float64
#  6   year                 398 non-null    int64
#  7   name                 398 non-null    int32
#  8   Kilometer_per_liter  398 non-null    float64
# dtypes: float64(4), int32(1), int64(4)
# memory usage: 26.6 KB

# %%
corr=df.corr()
corr
# Out:
#                        origin  cylinders  displacement  horsepower    weight  \
# origin               1.000000  -0.562543     -0.609409   -0.452096 -0.581024
# cylinders           -0.562543   1.000000      0.950721    0.841284  0.896017
# displacement        -0.609409   0.950721      1.000000    0.895778  0.932824
# horsepower          -0.452096   0.841284      0.895778    1.000000  0.862442
# weight              -0.581024   0.896017      0.932824    0.862442  1.000000
# acceleration         0.205873  -0.505419     -0.543684   -0.686590 -0.417457
# year                 0.180662  -0.348746     -0.370164   -0.413733 -0.306564
# name                 0.360058  -0.275754     -0.292064   -0.233575 -0.255247
# Kilometer_per_liter  0.563450  -0.775396     -0.804203   -0.773453 -0.831741
#
#                      acceleration      year      name  Kilometer_per_liter
# origin                   0.205873  0.180662  0.360058             0.563450
# ...

# %%
df_col=df[['Kilometer_per_liter']]

# %%
df_col.head()
# Out:
#    Kilometer_per_liter
# 0             7.652587
# 1             6.377156
# 2             7.652587
# 3             6.802299
# 4             7.227443

# %%
a=corr[['Kilometer_per_liter']]
a
# Out:
#                      Kilometer_per_liter
# origin                          0.563450
# cylinders                      -0.775396
# displacement                   -0.804203
# horsepower                     -0.773453
# weight                         -0.831741
# acceleration                    0.420289
# year                            0.579267
# name                            0.273936
# Kilometer_per_liter             1.000000

# %%
df.drop(['cylinders','displacement','horsepower','weight'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    origin  acceleration  year  name  Kilometer_per_liter
# 0       1          12.0  1970    49             7.652587
# 1       1          11.5  1970    36             6.377156
# 2       1          11.0  1970   231             7.652587
# 3       1          12.0  1970    14             6.802299
# 4       1          10.5  1970   161             7.227443

# %%
b=df.corr()
b
# Out:
#                        origin  acceleration      year      name  \
# origin               1.000000      0.205873  0.180662  0.360058
# acceleration         0.205873      1.000000  0.288137  0.128285
# year                 0.180662      0.288137  1.000000  0.074761
# name                 0.360058      0.128285  0.074761  1.000000
# Kilometer_per_liter  0.563450      0.420289  0.579267  0.273936
#
#                      Kilometer_per_liter
# origin                          0.563450
# acceleration                    0.420289
# year                            0.579267
# name                            0.273936
# Kilometer_per_liter             1.000000

# %%
a1 = b[['Kilometer_per_liter']]
a1
# Out:
#                      Kilometer_per_liter
# origin                          0.563450
# acceleration                    0.420289
# year                            0.579267
# name                            0.273936
# Kilometer_per_liter             1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,15))
sns.heatmap(a1,cmap='BrBG',vmax=1.0,vmin=-1.0,fmt='g',annot=True)
plt.title('Mileage_Matrix',fontsize=20)
plt.show()

# %%
df.columns
# Out:
# Index(['origin', 'acceleration', 'year', 'name', 'Kilometer_per_liter'], dtype='object')

# %%
X=df[['origin', 'acceleration', 'year', 'name']]

# %%
y=df[['Kilometer_per_liter']]

# %%
#Independent variables
X.head()
# Out:
#    origin  acceleration  year  name
# 0       1          12.0  1970    49
# 1       1          11.5  1970    36
# 2       1          11.0  1970   231
# 3       1          12.0  1970    14
# 4       1          10.5  1970   161

# %%
#Dependent Variable
y.head()
# Out:
#    Kilometer_per_liter
# 0             7.652587
# 1             6.377156
# 2             7.652587
# 3             6.802299
# 4             7.227443

# %%
x=X.values.reshape(-1,1)

# %%
y=y.values.reshape(-1,1)

# %%
#train_test_split
from sklearn.model_selection import train_test_split

# %%
#splitting of data
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,train_size=0.7,random_state=1)

# %%
X_train.shape
# Out:
# (278, 4)

# %%
X_test.shape
# Out:
# (120, 4)

# %%
X.shape
# Out:
# (398, 4)

# %%
y_train.shape
# Out:
# (278, 1)

# %%
y_test.shape
# Out:
# (120, 1)

# %%
y.shape
# Out:
# (398, 1)

# %%
#importing Linear regression
from sklearn.linear_model import LinearRegression

# %%
#Object creaton
model=LinearRegression()

# %%
#training the model using .fit() function
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#testing the data/model or predicting the data or predicting the model (y^)
y_pred=model.predict(X_test)
y_pred
# Out:
# array([[ 8.48802402],
#        [14.26146109],
#        [ 9.27224073],
#        [11.28690138],
#        [10.63340893],
#        [ 9.32826352],
#        [10.45069125],
#        [15.28241188],
#        [ 8.30810366],
#        [ 7.30460495],
#        [11.58728297],
#        [10.60128105],
#        [ 9.42375232],
#        [10.09537558],
#        [15.17751435],
#        [10.52514674],
#        [ 5.22621437],
#        [ 8.77672175],
#        [ 7.00761043],
#        [14.33683091],
#        [12.14740604],
#        [11.32912463],
#        [ 6.78154644],
#        [ 9.87553078],
#        [11.52232937],
#        [11.34038776],
#        [15.11880561],
#        [14.2788945 ],
#        [ 5.41399504],
#        [11.12970398],
#        [11.47763264],
#        [ 4.70862839],
#        [10.30253358],
#        [13.22949397],
#        [ 9.98528136],
#        [ 6.88198185],
#        [ 9.55695052],
#        [ 6.38469043],
#        [10.53615142],
#        [ 8.42964367],
#        [ 7.72840701],
# ...

# %%
from sklearn.metrics import r2_score

# %%
#counting R2 score by
r2_score(y_test,y_pred)*100
# Out:
# 64.7861362115629

# %%
model.score(X_test,y_test)*100
# Out:
# 64.7861362115629

# %%
model.score(X_train,y_train)*100
# Out:
# 56.816378762894274

# %%
#Adjusted R_square
adj_r2_score=1-(1-model.score(X_test,y_test))*len((y_train)-1)/(len(y_train)-y_test.shape[1]-1)
adj_r2_score
# Out:
# 0.6453096328555974

# %%
adj_r2_score*100
# Out:
# 64.53096328555974

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 3.7213075829986635

# %%
sns.regplot(x=X_test['acceleration'],y=y_test,truncate=False)
# Out:
# <AxesSubplot:xlabel='acceleration'>

# %%
model.intercept_
# Out:
# array([-815.09083447])
